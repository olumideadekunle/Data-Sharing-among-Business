# %% [markdown]
# <a href="https://colab.research.google.com/github/olumideadekunle/Data-Sharing-among-Business/blob/main/Copy_of_Question_Mini_Project_Module_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evaluating the Impact of Marketing Campaigns
#
# In a fast paced world like we experience daily, every company seeks one means of the other to maintain profitability and gain quantifiable market share. For marketing companies they focus on consistently running successful campaigns in a complex and competitive market.
#
# For this to be possible, they set up on A/B testing systems, a randomized experimentation method that involves presenting different versions of a variable (such as a web page, banner, or ad) to separate segments of the audience simultaneously. This approach helps determine which version has the most significant impact on business metrics.
#
# To address these questions, the company conducted an A/B test, where the majority of participants were exposed to ads (the experimental group) and a smaller portion saw a Public Service Announcement (PSA) or nothing (the control group).
#
# ## About the Dataset
#
# | **Feature**         | **Description**                                                                                 |
# |--------------------|-------------------------------------------------------------------------------------------------|
# | **Row Index**      | Row index                                                                                      |
# | **User ID**        | Unique identifier for each user                                                                |
# | **Test Group**     | Indicates whether the user was in the "ad" group (saw the advertisement) or the "psa" group (saw the public service announcement or nothing) |
# | **Converted**      | Indicates whether the user bought the product (True) or not (False)                            |
# | **Total Ads**      | The number of ads seen by the user                                                             |
# | **Most Ads Day**   | The day when the user saw the highest number of ads                                            |
# | **Most Ads Hour**  | The hour of the day when the user saw the highest number of ads                                |
#
# The marketing data can be found **[here](https://drive.google.com/file/d/1YDS_6_1sCJPjucNX6Feo9uGa8B3w8Xzk/view?usp=sharing)**.
#
# ## Objective
#
# The primary objective of this case study is to perform hypothesis testing on the e-commerce dataset to compare different groups or features. Specifically, we aim to:
#
# - Analyze the experimental and control groups to determine if the ads were successful.
#
# - Estimate the potential revenue generated from the ads.
#
# - Assess the statistical significance of the differences between the groups using A/B testing techniques.

# %% [markdown]
# The dataset contains 588,101 records and 7 columns:
#
#
# Column	Description
# Unnamed: 0	Row index (can be dropped)
# user id	Unique identifier for each user
# test group	Either "ad" (experimental group) or "psa" (control group)
# converted	True if the user made a purchase, otherwise False
# total ads	Number of ads seen by the user
# most ads day	Day the user saw the most ads
# most ads hour	Hour of the day the user saw the most ads

# %% [markdown]
# | Test Group | Total Users | Conversions | Conversion Rate |
# |------------|-------------|-------------|-----------------|
# | Ad         | 564,577     | 14,423      | 2.55%           |
# | PSA        | 23,524      | 420         | 1.79%           |

# %% [markdown]
#  Initial Insight:
# The ad group had a higher conversion rate (2.55%) compared to the PSA group (1.79%).

# %% [markdown]
# ✅ **Z-test Results:**
#
# - **Z-statistic:** 7.37
# - **P-value:** ~1.71 × 10⁻¹³
#
# 📌 **Interpretation:**
# Since the p-value is **far below 0.05**, we **reject the null hypothesis**. This means the difference in conversion rates between the ad group and the PSA group is **statistically significant** — the ads had a **measurable positive impact** on conversions.
#
# Would you like to estimate potential revenue from the ads based on assumed product price, or explore visualizations and further breakdowns (e.g., by day or hour)?

# %% [markdown]
# If each product sells for $50:
#
# The ad group had 14,423 conversions, so their estimated revenue = 14,423 × $50 = $721,150.
#
# The psa group had 420 conversions, so revenue = 420 × $50 = $21,000.
#
# The incremental revenue from the ad campaign = $721,150 - $21,000 = $700,150.
#
# This suggests that the ad campaign potentially generated over $700K more in revenue compared to not running the ad.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load and clean the dataset
# The previous file path was likely incorrect for your current environment.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load and clean the dataset
# The previous file path was likely incorrect for your current environment.
# Update the path to the actual location of your 'marketing_AB.csv' file.
df = pd.read_csv("C:/Users/SAIL/OneDrive/Desktop/3MTT/marketing_AB.csv")  # Replace with the correct path
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df.drop(columns=["unnamed:_0"], inplace=True)

# Calculate conversion rates by day and group
day_conversion = df.groupby(["most_ads_day", "test_group"])["converted"].mean().reset_index()

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=day_conversion, x="most_ads_day", y="converted", hue="test_group")
plt.title("Conversion Rate by Day and Test Group")
plt.ylabel("Conversion Rate")
plt.xlabel("Day of the Week")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Calculate conversion rates by day and group
day_conversion = df.groupby(["most_ads_day", "test_group"])["converted"].mean().reset_index()

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=day_conversion, x="most_ads_day", y="converted", hue="test_group")
plt.title("Conversion Rate by Day and Test Group")
plt.ylabel("Conversion Rate")
plt.xlabel("Day of the Week")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-59a3e8c9b109> in <cell line: 0>()
#      12 # The previous file path was likely incorrect for your current environment.
#      13 # Update the path to the actual location of your 'marketing_AB.csv' file.
# ---> 14 df = pd.read_csv("C:/Users/SAIL/OneDrive/Desktop/3MTT/marketing_AB.csv")  # Replace with the correct path
#      15 df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
#      16 df.drop(columns=["unnamed:_0"], inplace=True)
#
# ...

# %% [markdown]
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Load and clean the dataset
# # Provide the correct file path to 'marketing_AB.csv'
# # If it's in a different folder, use the relative or absolute path
# # For example:
# # df = pd.read_csv("data/marketing_AB.csv")  # If it's in a 'data' subfolder
# df = pd.read_csv("C:/Users/DOCUMENTS/3MTT DATA SCICENCE/marketing_AB.csv")  # Replace with your actual path
# df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
# df.drop(columns=["unnamed:_0"], inplace=True)
#
# # Calculate conversion rates by day and group
# day_conversion = df.groupby(["most_ads_day", "test_group"])["converted"].mean().reset_index()
#
# # Plot
# plt.figure(figsize=(12, 6))
# sns.barplot(data=day_conversion, x="most_ads_day", y="converted", hue="test_group")
# plt.title("Conversion Rate by Day and Test Group")
# plt.ylabel("Conversion Rate")
# plt.xlabel("Day of the Week")
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-31a415a0-81f7-4e0e-8665-50ca4c93f01d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31a415a0-81f7-4e0e-8665-50ca4c93f01d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Encoding
 handle = open(
# Then use the correct path in Google Drive
df = pd.read_csv("/content/drive/MyDrive/3mtt Data Science/marketing_AB.csv")


                 if ioargs.encoding and "b" not in ioargs.mode:
    872             # Encoding
--> 873             handle = open(
    874                 handle,
    875                 ioargs.mode,
# Out:
#   File "<ipython-input-25-ea9daed61e26>", line 4
#     handle = open(
#     ^
# IndentationError: unexpected indent

# %%
from google.colab import drive
drive.mount('/content/drive')

# Then use the correct path in Google Drive
df = pd.read_csv("/content/drive/MyDrive/3mtt Data Science/marketing_AB.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-8556242a27f6> in <cell line: 0>()
#       3
#       4 # Then use the correct path in Google Drive
# ----> 5 df = pd.read_csv("/content/drive/MyDrive/3mtt Data Science/marketing_AB.csv")
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load and prepare the dataset
df = pd.read_csv("marketing_AB.csv")
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df.drop(columns=["unnamed:_0"], inplace=True)

# Calculate conversion rates by hour and group
hour_conversion = df.groupby(["most_ads_hour", "test_group"])["converted"].mean().reset_index()

# Plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=hour_conversion, x="most_ads_hour", y="converted", hue="test_group", marker="o")
plt.title("Conversion Rate by Hour and Test Group")
plt.ylabel("Conversion Rate")
plt.xlabel("Hour of the Day")
plt.xticks(range(0, 24))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

df = pd.read_csv("marketing_AB.csv")  # File now exists in Colab environment
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df.drop(columns=["unnamed:_0"], inplace=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Checking for missing values
df.isnull().sum()

# Dropping rows with missing values (if necessary)
df.dropna(inplace=True)

# Renaming columns to standardize them for easier access
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# Displaying the first few rows to ensure data is loaded properly
df.head()
# Out:
#    user_id test_group  converted  total_ads most_ads_day  most_ads_hour
# 0  1069124         ad      False        130       Monday             20
# 1  1119715         ad      False         93      Tuesday             22
# 2  1144181         ad      False         21      Tuesday             18
# 3  1435133         ad      False        355      Tuesday             10
# 4  1015700         ad      False        276       Friday             14

# %%
# Summary statistics for all numerical columns
df.describe()

# Grouping data by test group
df.groupby('test_group').describe()
# Out:
#              user_id                                                      \
#                count          mean            std        min         25%
# test_group
# ad          564577.0  1.327314e+06  188918.061566  1000000.0  1163686.00
# psa          23524.0  9.117615e+05    6790.938202   900000.0   905880.75
#
#                                              total_ads             ...        \
#                   50%         75%        max     count       mean  ...   75%
# test_group                                                         ...
# ad          1327362.0  1490914.00  1654483.0  564577.0  24.823365  ...  27.0
# psa          911761.5   917642.25   923523.0   23524.0  24.761138  ...  26.0
#
#                    most_ads_hour                                              \
#                max         count       mean       std  min   25%   50%   75%
# test_group
# ad          2065.0      564577.0  14.475900  4.841808  0.0  11.0  14.0  18.0
# ...

# %%
# Conversion rate by test group
conversion_rate_by_group = df.groupby('test_group')['converted'].mean()
print(conversion_rate_by_group)
# Out:
# test_group
# ad     0.025547
# psa    0.017854
# Name: converted, dtype: float64

# %%
# Extracting conversion data for both groups
ad_group = df[df['test_group'] == 'ad']['converted']
psa_group = df[df['test_group'] == 'psa']['converted']

# Performing t-test
t_stat, p_value = stats.ttest_ind(ad_group, psa_group)
print(f'T-statistic: {t_stat}, P-value: {p_value}')
# Out:
# T-statistic: -inf, P-value: nan

# %%
# Assume the price of the product is $100 (example)
product_price = 100

# Estimating revenue for each group
ad_revenue = ad_group.sum() * product_price
psa_revenue = psa_group.sum() * product_price

print(f"Estimated revenue from ads: ${ad_revenue}")
print(f"Estimated revenue from PSA: ${psa_revenue}")
# Out:
# Estimated revenue from ads: $1442300
# Estimated revenue from PSA: $42000

# %%
# Bar plot for conversion rates
sns.barplot(x=conversion_rate_by_group.index, y=conversion_rate_by_group.values)
plt.title('Conversion Rates by Group')
plt.xlabel('Group')
plt.ylabel('Conversion Rate')
plt.show()
